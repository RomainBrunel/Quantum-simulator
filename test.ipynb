# %%
import numpy as np
from gates import *

# %%
state = quantum_state()
state.generate_rdm_state()

circuit = {"H":0,"X":0,"Z":0,"H":0,"Y":0,"S":0.6,"H":0,"S":6}
sim = one_qubit_simulator(circuit)

# %%
sim.run_simulation(state)
# Out:
# array([ 0.40517965+0.57950794j, -0.40517965+0.57950794j])

# %%
state.plot_state()
